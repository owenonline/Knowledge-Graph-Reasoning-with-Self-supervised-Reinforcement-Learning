# %%
import re
import matplotlib.pyplot as plt
import numpy as np
text = ""
scores = ""

def moving_average(a, n=3) :
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret[n - 1:] / n

logs = [
    "../output/nell/afe4_top25%_NELL995_new_SL/log.txt",
    "../output/nell/0b41_hilrtop25%_NELL995_new_SL/log.txt",
    "../output/nell/2d79_ignore75%_NELL995_new_SL/log.txt",
    "../output/nell/9c05_ignore50%_NELL995_new_SL/log.txt",
    "../output/nell/ec8e_ignore25%_NELL995_new_SL/log.txt",
    
]

scores = [
    "../output/nell/afe4_top25%_NELL995_new_SL/scores.txt",
    "../output/nell/0b41_hilrtop25%_NELL995_new_SL/scores.txt",
    "../output/nell/2d79_ignore75%_NELL995_new_SL/scores.txt",
    "../output/nell/9c05_ignore50%_NELL995_new_SL/scores.txt",
    "../output/nell/ec8e_ignore25%_NELL995_new_SL/scores.txt",
]

# set this to switch logs
trialnum = 3

with open(logs[trialnum], "r") as logfile:
    text = logfile.read()
    
with open(scores[trialnum], "r") as scorefile:
    scores = scorefile.read()
    scores = scores.split("\n\n")
    
for index in range(len(scores)):
    scores[index] = np.array([float(x) for x in re.findall("[0-9]*\.[0-9]*", scores[index])])
    
text = text[255:]
text = re.sub('.*\/.*\/.*\[ (?!RL).*\n', '', text)
text = text.split("\n")
datablocks = []
print(len(text))
if trialnum == 0:
    for i in range(1, 41):
        datablocks.append('\n'.join(text[(i - 1)*2000 : i*2000]))
else:
    for i in range(1, 21):
        if i%2 != 0:
            even = ((i - 1)/2)*1500 # even corresponds to SL
            odd = (((i - 1)/2) + 1)*1000 # odd corresponds to RL
            base = int(even + odd - 1000)
            end = int(even + odd)
#             print("[Odd] | base: {}\tend: {}".format(base, end))
            datablocks.append('\n'.join(text[base : end]))
        else:
            even = (i/2)*1500
            odd = (i/2)*1000
            base = int(even + odd - 1500)
            end = int(even + odd)
#             print("[Even] | base: {}\tend: {}".format(base, end))
            datablocks.append('\n'.join(text[base : end]))

for count, value in enumerate(datablocks):
    datablocks[count] = re.sub(".*\/.*avg_ep_correct  ", "", value)
    datablocks[count] = re.sub(", .*\]", ",", datablocks[count])
    datablocks[count] = re.sub("\n", "", datablocks[count])
    datablocks[count] = datablocks[count][:-1].split(',')
    datablocks[count] = [float(x) for x in datablocks[count]]

groups = []
for i in range(1, len(datablocks), 2):
    groups.append(datablocks[i])
    
for count, group in enumerate(groups):
    group = moving_average(group, n=50)
    plt.plot(list(range(len(group))), group)
    plt.show()
    if count == 0:
        print("Hits@1: {}\nHits@3: {}\nHits@5: {}\nHits@10: {}\nHits@20: {}\nauc: {}".format(scores[count][0], scores[count][1], scores[count][2], scores[count][3], scores[count][4], scores[count][5]))
    elif count > 0 and count < 19:
        diff = np.divide(np.subtract(scores[count], scores[count - 1]), scores[count - 1])*100
        print("Hits@1: {}\nHits@3: {}\nHits@5: {}\nHits@10: {}\nHits@20: {}\nauc: {}".format(diff[0], diff[1], diff[2], diff[3], diff[4], diff[5]))
    plt.clf()
# Out:
# 25001
# [Odd] | base: 0	end: 1000
# [Even] | base: 1000	end: 2500
# [Odd] | base: 2500	end: 3500
# [Even] | base: 3500	end: 5000
# [Odd] | base: 5000	end: 6000
# [Even] | base: 6000	end: 7500
# [Odd] | base: 7500	end: 8500
# [Even] | base: 8500	end: 10000
# [Odd] | base: 10000	end: 11000
# [Even] | base: 11000	end: 12500
# [Odd] | base: 12500	end: 13500
# [Even] | base: 13500	end: 15000
# [Odd] | base: 15000	end: 16000
# [Even] | base: 16000	end: 17500
# [Odd] | base: 17500	end: 18500
# [Even] | base: 18500	end: 20000
# [Odd] | base: 20000	end: 21000
# [Even] | base: 21000	end: 22500
# [Odd] | base: 22500	end: 23500
# [Even] | base: 23500	end: 25000
# Hits@1: 0.6848
# Hits@3: 0.7891
# Hits@5: 0.8186
# Hits@10: 0.8367
# Hits@20: 0.8458
# auc: 0.7445
# Hits@1: -7.943925233644861
# Hits@3: 2.0149537447725288
# Hits@5: -0.8306865379916966
# Hits@10: -0.8127166248356674
# Hits@20: -1.6079451406951932
# auc: -3.505708529214239
# Hits@1: -6.123096446700503
# Hits@3: -0.8447204968944133
# Hits@5: 0.0
# Hits@10: -0.8193758284130518
# Hits@20: 1.3578466714732007
# auc: -3.0762806236080187
# Hits@1: 17.2524501520784
# Hits@3: -1.4282134803307398
# Hits@5: -1.9586104951958505
# Hits@10: -1.372858704896135
# Hits@20: -2.4184943687018343
# auc: 6.548901335631189
# Hits@1: -4.899841475716951
# Hits@3: 1.741230299949153
# Hits@5: 1.4323407463249107
# Hits@10: 1.9586104951958645
# Hits@20: 1.385007896974847
# auc: -1.6444264725704256
# Hits@1: 4.803758145173504
# Hits@3: -0.574640849469074
# Hits@5: -0.284900284900281
# Hits@10: -1.643107406064993
# Hits@20: -0.8148591971240297
# auc: 2.01452651774701
# Hits@1: -5.248698669751302
# Hits@3: -1.1433597185576072
# Hits@5: -1.1304347826086951
# Hits@10: 0.0
# Hits@20: -0.5557569167572716
# auc: -3.277807630306284
# Hits@1: 4.85273920341829
# Hits@3: 2.313167259786476
# Hits@5: 1.4323407463249107
# Hits@10: 0.2702370716128215
# Hits@20: 0.27943141781071174
# auc: 3.444444444444451
# Hits@1: -17.828554795517398
# Hits@3: -3.6645962732919353
# Hits@5: -1.1272141706924312
# Hits@10: 0.28175915717260425
# Hits@20: 0.823842985219291
# auc: -9.532760472610105
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [130], in <cell line: 78>()
#      83     print("Hits@1: {}\nHits@3: {}\nHits@5: {}\nHits@10: {}\nHits@20: {}\nauc: {}".format(scores[count][0], scores[count][1], scores[count][2], scores[count][3], scores[count][4], scores[count][5]))
#      84 elif count > 0 and count < 19:
# ---> 85     diff = np.divide(np.subtract(scores[count], scores[count - 1]), scores[count - 1])*100
#      86     print("Hits@1: {}\nHits@3: {}\nHits@5: {}\nHits@10: {}\nHits@20: {}\nauc: {}".format(diff[0], diff[1], diff[2], diff[3], diff[4], diff[5]))
#      87 plt.clf()
#
# ValueError: operands could not be broadcast together with shapes (0,) (6,)
